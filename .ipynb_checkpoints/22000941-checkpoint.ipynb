# %%
installed.packages()
# Out:
#              Package      LibPath
# base64enc    base64enc    C:/Users/abina/AppData/Local/R/win-library/4.4
# cli          cli          C:/Users/abina/AppData/Local/R/win-library/4.4
# colorspace   colorspace   C:/Users/abina/AppData/Local/R/win-library/4.4
# crayon       crayon       C:/Users/abina/AppData/Local/R/win-library/4.4
# digest       digest       C:/Users/abina/AppData/Local/R/win-library/4.4
# evaluate     evaluate     C:/Users/abina/AppData/Local/R/win-library/4.4
# fansi        fansi        C:/Users/abina/AppData/Local/R/win-library/4.4
# farver       farver       C:/Users/abina/AppData/Local/R/win-library/4.4
# fastmap      fastmap      C:/Users/abina/AppData/Local/R/win-library/4.4
# ggplot2      ggplot2      C:/Users/abina/AppData/Local/R/win-library/4.4
# glue         glue         C:/Users/abina/AppData/Local/R/win-library/4.4
# gtable       gtable       C:/Users/abina/AppData/Local/R/win-library/4.4
# ...

# %%
library(ggplot2)

# %%
ggplot(mtcars, aes(x = wt, y = mpg)) + geom_point()
# Out:
# plot without title
